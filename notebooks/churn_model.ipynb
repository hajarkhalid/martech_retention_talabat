# %% [markdown]
# # Churn model (starter)
# Loads features, trains a simple classifier, saves predictions back to BigQuery.

# %%
from google.cloud import bigquery
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

client = bigquery.Client()
df = client.query("SELECT * FROM `{{PROJECT}}.{{DATASET}}.features_user_basic` LIMIT 10000").to_dataframe()
print(df.head())
