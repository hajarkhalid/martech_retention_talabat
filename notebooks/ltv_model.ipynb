# %% [markdown]
# # LTV model (starter)
# Feature engineering + regression to estimate future spend.

# %%
from google.cloud import bigquery
import pandas as pd
from sklearn.linear_model import LinearRegression

client = bigquery.Client()
df = client.query("SELECT * FROM `{{PROJECT}}.{{DATASET}}.features_user_orders` LIMIT 10000").to_dataframe()
print(df.head())
