# %% [markdown]
# # Voucher elasticity
# Load voucher_elasticity table, run regression of revenue ~ voucher_spend.

# %%
from google.cloud import bigquery
import statsmodels.api as sm
client = bigquery.Client()
df = client.query("SELECT * FROM `{{PROJECT}}.{{DATASET}}.voucher_elasticity` LIMIT 1000").to_dataframe()
print(df.head())
